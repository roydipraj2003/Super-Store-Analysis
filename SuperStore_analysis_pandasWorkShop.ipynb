# %% [markdown]
# # First Pandas library Workshope
#   - pandas library use to work with data frame

# %%
import pandas as pd # import the library

# %%
pd.__version__ # check the version of the library
# Out:
# '2.2.2'

# %%
# here we load the data set to the system 
store = pd.read_csv(r"C:\Users\sunil\Desktop\Data Science and AI NIT\21th- pandas workshope\Sample - Superstore_Orders.csv")
# read_csv() help to read the csv(comma separated value file) fromsystem

# %%
store # print the data set
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
len(store) # check the length of the data set by using len()
# Out:
# 10194

# %%
store.columns # here we check how much columns the data set have using columns atribute
# Out:
# Index(['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category',
#        'Discount', 'Profit', 'Quantity', 'Sales'],
#       dtype='object')

# %%
store.shape # shape attribute give the result that how much the rows and columns have the data set
# Out:
# (10194, 19)

# %%
store.isnull() # isnull() function use to check wheather the data set have any null value or not, if any null value there then its return true
# Out:
#        Category   City  Country/Region  Customer Name  Manufacturer  \
# 0         False  False           False          False         False
# 1         False  False           False          False         False
# 2         False  False           False          False         False
# 3         False  False           False          False         False
# 4         False  False           False          False         False
# ...         ...    ...             ...            ...           ...
# 10189     False  False           False          False         False
# 10190     False  False           False          False         False
# 10191     False  False           False          False         False
# 10192     False  False           False          False         False
# 10193     False  False           False          False         False
#
#        Order Date  Order ID  Postal Code  Product Name  Region  Segment  \
# 0           False     False        False         False   False    False
# ...

# %%
store.isnull().sum() # isnull().sum() to count the number of missing (null) values in each column of a DataFrame.
# Out:
# Category          0
# City              0
# Country/Region    0
# Customer Name     0
# Manufacturer      0
# Order Date        0
# Order ID          0
# Postal Code       0
# Product Name      0
# Region            0
# Segment           0
# Ship Date         0
# Ship Mode         0
# State/Province    0
# Sub-Category      0
# Discount          0
# Profit            0
# Quantity          0
# Sales             0
# dtype: int64

# %%
store.isna() # isna() function is also used to find the nul value preswnt in the data frameor not
# Out:
#        Category   City  Country/Region  Customer Name  Manufacturer  \
# 0         False  False           False          False         False
# 1         False  False           False          False         False
# 2         False  False           False          False         False
# 3         False  False           False          False         False
# 4         False  False           False          False         False
# ...         ...    ...             ...            ...           ...
# 10189     False  False           False          False         False
# 10190     False  False           False          False         False
# 10191     False  False           False          False         False
# 10192     False  False           False          False         False
# 10193     False  False           False          False         False
#
#        Order Date  Order ID  Postal Code  Product Name  Region  Segment  \
# 0           False     False        False         False   False    False
# ...

# %%
store.isna().sum() # to count the number of missing (null) values in each column of a DataFrame.
# Out:
# Category          0
# City              0
# Country/Region    0
# Customer Name     0
# Manufacturer      0
# Order Date        0
# Order ID          0
# Postal Code       0
# Product Name      0
# Region            0
# Segment           0
# Ship Date         0
# Ship Mode         0
# State/Province    0
# Sub-Category      0
# Discount          0
# Profit            0
# Quantity          0
# Sales             0
# dtype: int64

# %%
store.head() # head() function usedto retrive first five rows from the data set
# Out:
#           Category          City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
# 1  Office Supplies    Naperville  United States  Phillina Ober           GBC
# 2  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 3  Office Supplies    Naperville  United States  Phillina Ober         SAFCO
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77095
# 1  04-01-2020  US-2020-112326       60540
# 2  04-01-2020  US-2020-112326       60540
# 3  04-01-2020  US-2020-112326       60540
# 4  05-01-2020  US-2020-141817       19143
#
#                                         Product Name   Region      Segment  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central     Consumer
# 1         GBC Standard Plastic Binding Systems Combs  Central  Home Office
# ...

# %%
store.tail() # tail() function used to retrive the last five rows from the data set
# Out:
#               Category           City Country/Region      Customer Name  \
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# 10189  Wilson Jones  30-12-2023  US-2023-143259       10009
# 10190           GBC  30-12-2023  US-2023-115427       94533
# 10191         Other  30-12-2023  US-2023-156720       80538
# 10192         Other  30-12-2023  US-2023-143259       10009
# 10193  Wilson Jones  30-12-2023  CA-2023-143500         C0A
#
#                                Product Name Region    Segment   Ship Date  \
# 10189  Wilson Jones Legal Size Ring Binders   East   Consumer  03-01-2024
# ...

# %%
store.head(2) # retrive first 2 rows
# Out:
#           Category        City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies     Houston  United States  Darren Powers  Message Book
# 1  Office Supplies  Naperville  United States  Phillina Ober           GBC
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77095
# 1  04-01-2020  US-2020-112326       60540
#
#                                         Product Name   Region      Segment  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central     Consumer
# 1         GBC Standard Plastic Binding Systems Combs  Central  Home Office
#
#     Ship Date       Ship Mode State/Province Sub-Category  Discount  Profit  \
# 0  07-01-2020  Standard Class          Texas        Paper       0.2  5.5512
# 1  08-01-2020  Standard Class       Illinois      Binders       0.8 -5.4870
#
#    Quantity   Sales
# 0         2  16.448
# 1         2   3.540

# %%
store[:] # slicing on data frame same as the list slicing
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store[::-1] # return the data frame into reverse order
# Out:
#               Category           City Country/Region      Customer Name  \
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# ...                ...            ...            ...                ...
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 0      Office Supplies        Houston  United States      Darren Powers
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store[1:10:3] # slicing the data frame from 1st index row till 10 index row 10th excluded, with step count is 3
# Out:
#           Category          City Country/Region  Customer Name Manufacturer  \
# 1  Office Supplies    Naperville  United States  Phillina Ober          GBC
# 4  Office Supplies  Philadelphia  United States     Mick Brown        Avery
# 7  Office Supplies        Athens  United States  Jack O'Briant        Dixon
#
#    Order Date        Order ID Postal Code  \
# 1  04-01-2020  US-2020-112326       60540
# 4  05-01-2020  US-2020-141817       19143
# 7  06-01-2020  US-2020-106054       30605
#
#                                         Product Name   Region      Segment  \
# 1         GBC Standard Plastic Binding Systems Combs  Central  Home Office
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...     East     Consumer
# 7  Dixon Prang Watercolor Pencils, 10-Color Set w...    South    Corporate
#
#     Ship Date       Ship Mode State/Province Sub-Category  Discount  Profit  \
# 1  08-01-2020  Standard Class       Illinois      Binders       0.8 -5.4870
# ...

# %%
store.info() # info() use to get the data frame information whether any empty value are there or not
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        10194 non-null  object
#  1   City            10194 non-null  object
#  2   Country/Region  10194 non-null  object
#  3   Customer Name   10194 non-null  object
#  4   Manufacturer    10194 non-null  object
#  5   Order Date      10194 non-null  object
#  6   Order ID        10194 non-null  object
#  7   Postal Code     10194 non-null  object
#  8   Product Name    10194 non-null  object
#  9   Region          10194 non-null  object
#  10  Segment         10194 non-null  object
#  11  Ship Date       10194 non-null  object
#  12  Ship Mode       10194 non-null  object
#  13  State/Province  10194 non-null  object
#  14  Sub-Category    10194 non-null  object
#  15  Discount        10194 non-null  float64
#  16  Profit          10194 non-null  float64
# ...

# %%
store["Category"] # retrive category columns from data frame
# Out:
# 0        Office Supplies
# 1        Office Supplies
# 2        Office Supplies
# 3        Office Supplies
# 4        Office Supplies
#               ...
# 10189    Office Supplies
# 10190    Office Supplies
# 10191    Office Supplies
# 10192         Technology
# 10193    Office Supplies
# Name: Category, Length: 10194, dtype: object

# %%
store[["Category",'Country/Region']] # retrive category and country/ region column from data frame
# Out:
#               Category Country/Region
# 0      Office Supplies  United States
# 1      Office Supplies  United States
# 2      Office Supplies  United States
# 3      Office Supplies  United States
# 4      Office Supplies  United States
# ...                ...            ...
# 10189  Office Supplies  United States
# 10190  Office Supplies  United States
# 10191  Office Supplies  United States
# 10192       Technology  United States
# 10193  Office Supplies         Canada
#
# [10194 rows x 2 columns]

# %%
store[["Category",'Country/Region','Manufacturer']] #retrive category and country/ region and manufacturer column from data frame
# Out:
#               Category Country/Region  Manufacturer
# 0      Office Supplies  United States  Message Book
# 1      Office Supplies  United States           GBC
# 2      Office Supplies  United States         Avery
# 3      Office Supplies  United States         SAFCO
# 4      Office Supplies  United States         Avery
# ...                ...            ...           ...
# 10189  Office Supplies  United States  Wilson Jones
# 10190  Office Supplies  United States           GBC
# 10191  Office Supplies  United States         Other
# 10192       Technology  United States         Other
# 10193  Office Supplies         Canada  Wilson Jones
#
# [10194 rows x 3 columns]

# %%
store.dtypes # dtypes use to check all the data type that the attribute hold values
# Out:
# Category           object
# City               object
# Country/Region     object
# Customer Name      object
# Manufacturer       object
# Order Date         object
# Order ID           object
# Postal Code        object
# Product Name       object
# Region             object
# Segment            object
# Ship Date          object
# Ship Mode          object
# State/Province     object
# Sub-Category       object
# Discount          float64
# Profit            float64
# Quantity            int64
# Sales             float64
# dtype: object

# %%
len(store.dtypes) # lenth of data frame
# Out:
# 19

# %%
store.columns
# Out:
# Index(['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category',
#        'Discount', 'Profit', 'Quantity', 'Sales'],
#       dtype='object')

# %%
store_categorical= store[['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
       'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
       'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category']] 
# retrive all the categorical(textual) data store in a variable

# %%
store_categorical.head() # from all categorical dataretrive first five rows
# Out:
#           Category          City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
# 1  Office Supplies    Naperville  United States  Phillina Ober           GBC
# 2  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 3  Office Supplies    Naperville  United States  Phillina Ober         SAFCO
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77095
# 1  04-01-2020  US-2020-112326       60540
# 2  04-01-2020  US-2020-112326       60540
# 3  04-01-2020  US-2020-112326       60540
# 4  05-01-2020  US-2020-141817       19143
#
#                                         Product Name   Region      Segment  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central     Consumer
# 1         GBC Standard Plastic Binding Systems Combs  Central  Home Office
# ...

# %%
store_numerical=store[['Discount', 'Profit', 'Quantity', 'Sales']] # retrive all numerical data store in a variable
store_numerical.info() # get information about the variable what the variable store
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Discount  10194 non-null  float64
#  1   Profit    10194 non-null  float64
#  2   Quantity  10194 non-null  int64
#  3   Sales     10194 non-null  float64
# dtypes: float64(3), int64(1)
# memory usage: 318.7 KB

# %%
store_numerical.dtypes # check the data type of the numerical data
# Out:
# Discount    float64
# Profit      float64
# Quantity      int64
# Sales       float64
# dtype: object

# %%
print(len(store.columns)) # retrive columns
print(len(store_categorical.columns))
print(len(store_numerical.columns))
# Out:
# 19
# 15
# 4

# %%
store
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store[0:50] # starting from 0th row to 49th row
# Out:
#            Category            City Country/Region      Customer Name  \
# 0   Office Supplies         Houston  United States      Darren Powers
# 1   Office Supplies      Naperville  United States      Phillina Ober
# 2   Office Supplies      Naperville  United States      Phillina Ober
# 3   Office Supplies      Naperville  United States      Phillina Ober
# 4   Office Supplies    Philadelphia  United States         Mick Brown
# 5         Furniture       Henderson  United States      Maria Etezadi
# 6   Office Supplies       Henderson  United States      Maria Etezadi
# 7   Office Supplies          Athens  United States      Jack O'Briant
# 8   Office Supplies       Henderson  United States      Maria Etezadi
# 9   Office Supplies       Henderson  United States      Maria Etezadi
# 10  Office Supplies       Henderson  United States      Maria Etezadi
# 11  Office Supplies     Los Angeles  United States   Lycoris Saunders
# ...

# %%
store[1:100:5] # starting from 1st index row end index is (100-1),step count id 5
# Out:
#            Category           City Country/Region      Customer Name  \
# 1   Office Supplies     Naperville  United States      Phillina Ober
# 6   Office Supplies      Henderson  United States      Maria Etezadi
# 11  Office Supplies    Los Angeles  United States   Lycoris Saunders
# 16  Office Supplies         Laredo  United States      Melanie Seite
# 21        Furniture  San Francisco  United States       Brian Dahlen
# 26  Office Supplies   Bossier City  United States    Chris Selesnick
# 31       Technology   Bossier City  United States    Chris Selesnick
# 36  Office Supplies   Philadelphia  United States  Delfina Latchford
# 41  Office Supplies     Scottsdale  United States      Toby Swindell
# 46        Furniture      Jonesboro  United States       Hunter Lopez
# 51  Office Supplies       Westland  United States       Xylona Preis
# 56  Office Supplies    Los Angeles  United States      Mark Van Huff
# 61        Furniture        Toronto         Canada          Jane Waco
# ...

# %%
store_categorical
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store_categorical[::10]
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 10     Office Supplies      Henderson  United States      Maria Etezadi
# 20           Furniture          Dover  United States        Seth Vernon
# 30     Office Supplies  San Francisco  United States       Brian Dahlen
# 40     Office Supplies     Scottsdale  United States      Toby Swindell
# ...                ...            ...            ...                ...
# 10150  Office Supplies         Newark  United States    Dan Reichenbach
# 10160  Office Supplies  New York City  United States  Jennifer Ferguson
# 10170       Technology  New York City  United States  Jennifer Ferguson
# 10180  Office Supplies  New York City  United States       Michael Chen
# 10190  Office Supplies      Fairfield  United States         Erica Bern
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store_numerical
# Out:
#        Discount   Profit  Quantity    Sales
# 0           0.2   5.5512         2   16.448
# 1           0.8  -5.4870         2    3.540
# 2           0.2   4.2717         3   11.784
# 3           0.2 -64.7748         3  272.736
# 4           0.2   4.8840         3   19.536
# ...         ...      ...       ...      ...
# 10189       0.2  19.7910         3   52.776
# 10190       0.2   6.4750         2   20.720
# 10191       0.2  -0.6048         3    3.024
# 10192       0.0   2.7279         7   90.930
# 10193       0.2  -0.6048         3    3.024
#
# [10194 rows x 4 columns]

# %%
store_numerical[10:500:50] # start index is 10th index row end index is (500-1), step count is 50
# Out:
#      Discount    Profit  Quantity    Sales
# 10        0.0    3.0084         1    6.540
# 60        0.2    4.1028         3   25.248
# 110       0.0   22.9488         2   81.960
# 160       0.2   21.8352         6  436.704
# 210       0.0   75.9696         4  155.040
# 260       0.0   15.9180         4   45.480
# 310       0.0    6.6584         7   22.960
# 360       0.0   15.5520         5   32.400
# 410       0.0  129.3786         9  497.610
# 460       0.5 -216.9783         7  349.965

# %% [markdown]
# ## pandas library day-1 work shope
